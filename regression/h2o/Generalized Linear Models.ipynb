# %%
import h2o

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "20.0.1" 2023-04-18; OpenJDK Runtime Environment Homebrew (build 20.0.1); OpenJDK 64-Bit Server VM Homebrew (build 20.0.1, mixed mode, sharing)
#   Starting server from /opt/anaconda3/envs/localds/lib/python3.9/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/zk/3vgrnry578s2pljd4gcb7f6r0000gn/T/tmph6qlvjh_
#   JVM stdout: /var/folders/zk/3vgrnry578s2pljd4gcb7f6r0000gn/T/tmph6qlvjh_/h2o_szhuang_started_from_python.out
#   JVM stderr: /var/folders/zk/3vgrnry578s2pljd4gcb7f6r0000gn/T/tmph6qlvjh_/h2o_szhuang_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       America/Los_Angeles
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.1
# H2O_cluster_version_age:    25 days
# H2O_cluster_name:           H2O_from_python_szhuang_60b4pq
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.9.16 final
# --------------------------  ------------------------------

# %%
# Import the GLM estimator:
from h2o.estimators import H2OGeneralizedLinearEstimator

# %%
# Import the training data:
training_data = h2o.import_file("http://h2o-public-test-data.s3.amazonaws.com/smalldata/glm_test/gamma_dispersion_factor_9_10kRows.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# Set the predictors and response:
predictors = ["abs.C1.","abs.C2.","abs.C3.","abs.C4.","abs.C5."]
response = "resp"

# %%
# Build and train the model:
model = H2OGeneralizedLinearEstimator(family="gamma",
                                      lambda_=0,
                                      generate_variable_inflation_factors=True,
                                      fold_assignment="modulo",
                                      compute_p_values=True,
                                      nfolds=3,
                                      keep_cross_validation_models=True)

# %%
model.train(x=predictors, y=response, training_frame=training_data)
# Out:
# glm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OGeneralizedLinearEstimator : Generalized Linear Modeling
# Model Key: GLM_model_python_1699722648433_43
#
#
# GLM Model: summary
#     family    link     regularization    number_of_predictors_total    number_of_active_predictors    number_of_iterations    training_frame
# --  --------  -------  ----------------  ----------------------------  -----------------------------  ----------------------  -------------------------------------
#     gamma     inverse  None              5                             5                              5                       gamma_dispersion_factor_9_10kRows.hex
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 597.035198034533
# RMSE: 24.434303714952325
# MAE: 11.578817944739663
# RMSLE: 1.8209533021536004
# Mean Residual Deviance: 14.361300090097927
# R^2: 0.008298238090181043
# Null degrees of freedom: 9999
# Residual degrees of freedom: 9994
# Null deviance: 144615.24857806342
# Residual deviance: 143613.00090097927
#
# ModelMetricsRegressionGLM: glm
# ** Reported on cross-validation data. **
#
# MSE: 597.6773949038803
# RMSE: 24.447441479710722
# MAE: 11.580721760376678
# RMSLE: 1.8211045836807092
# Mean Residual Deviance: 14.369387806143745
# R^2: 0.007231520802957192
# Null degrees of freedom: 9999
# Residual degrees of freedom: 9994
# Null deviance: 144621.91919740592
# Residual deviance: 143693.87806143746
#
# Cross-Validation Metrics Summary:
#                         mean        sd           cv_1_valid    cv_2_valid    cv_3_valid
# ----------------------  ----------  -----------  ------------  ------------  ------------
# mae                     11.5807     0.128997     11.7295       11.5007       11.5119
# mean_residual_deviance  14.3694     0.175874     14.253        14.5717       14.2834
# mse                     597.675     28.4171      624.02        567.562       601.443
# null_deviance           48207.3     613.133      47835.4       48915         47871.5
# r2                      0.00720224  0.000825056  0.0066776     0.00815324    0.00677587
# residual_deviance       47898       581.511      47519.6       48567.5       47606.7
# rmse                    24.4428     0.582717     24.9804       23.8236       24.5243
# rmsle                   1.8211      0.00657558   1.81362       1.82598       1.82369
#
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective    training_rmse       training_deviance    training_mae        training_r2
# --  -------------------  ----------  ------------  -------------------------  -----------  ------------------  -------------------  ------------------  --------------------
#     2023-11-11 09:12:04  0.000 sec   0             144615                     14.4615
#     2023-11-11 09:12:04  0.015 sec   1             143792                     14.3792
#     2023-11-11 09:12:04  0.017 sec   2             143626                     14.3626
#     2023-11-11 09:12:04  0.028 sec   3             143613                     14.3613
#     2023-11-11 09:12:04  0.030 sec   4             143613                     14.3613
#     2023-11-11 09:12:04  0.033 sec   5             143613                     14.3613      24.434303714952325  14.361300090097927   11.578817944739663  0.008298238090181043
#
# Variable Importances:
# variable    relative_importance    scaled_importance    percentage
# ----------  ---------------------  -------------------  ------------
# abs.C5.     0.0230492              1                    0.290336
# abs.C4.     0.0207745              0.901309             0.261683
# abs.C3.     0.0174643              0.757695             0.219986
# abs.C2.     0.0113058              0.490509             0.142413
# abs.C1.     0.00679423             0.29477              0.0855825
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
model.coef_with_p_values()
# Out:
# Coefficients: glm coefficients
# names      coefficients    std_error    z_value    p_value      variable_inflation_factor    standardized_coefficients
# ---------  --------------  -----------  ---------  -----------  ---------------------------  ---------------------------
# Intercept  0.277082        0.0154922    17.8853    1.91331e-70  nan                          0.140059
# abs.C1.    -0.00236829     0.00125317   -1.88984   0.0588081    1.00033                      -0.00679423
# abs.C2.    -0.00389936     0.00124773   -3.12515   0.00178221   1.00017                      -0.0113059
# abs.C3.    -0.00602086     0.00126834   -4.74705   2.09268e-06  1.00078                      -0.0174643
# abs.C4.    -0.0071742      0.00127739   -5.61629   2.00324e-08  1.00054                      -0.0207745
# abs.C5.    -0.00796829     0.00128155   -6.2177    5.24664e-10  1.00053                      -0.0230492

# %%
model._model_json["output"]['model_summary']
# Out:
# GLM Model: summary
#     family    link     regularization    number_of_predictors_total    number_of_active_predictors    number_of_iterations    training_frame
# --  --------  -------  ----------------  ----------------------------  -----------------------------  ----------------------  -------------------------------------
#     gamma     inverse  None              5                             5                              5                       gamma_dispersion_factor_9_10kRows.hex
